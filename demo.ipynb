# %% [markdown]
# <a href="https://colab.research.google.com/github/swastikabiswas0258-tech/my-first-repo/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hi")
# Out:
# hi

# %%
import numpy as np
arr = np.array([[1,2],[3,4]])
print(arr)
# Out:
# [[1 2]
#  [3 4]]

# %%
arr.shape
# Out:
# (2, 2)

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame([[1,2,3],[4,5,6]])

print(df)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
import matplotlib.pyplot as plt
import numpy as np
xpts = np.array([0,4])
ypts = np.array([0,100])
plt.plot(xpts,ypts)
plt.show()
